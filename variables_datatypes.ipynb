# %% [markdown]
# <a href="https://colab.research.google.com/github/AdarshMane09/module-1-ai-python/blob/main/variables_datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Adarsh"
age = 20
percentage = 78.5
is_student = True

print("Name:", name)
print("Age:", age)
print("Percentage:", percentage)
print("Student:", is_student)

print(type(name))
print(type(age))
print(type(percentage))
print(type(is_student))
# Out:
# Name: Adarsh
# Age: 20
# Percentage: 78.5
# Student: True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
