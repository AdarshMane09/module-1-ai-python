# %% [markdown]
# <a href="https://colab.research.google.com/github/AdarshMane09/module-1-ai-python/blob/main/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet(name):
    print("Hello", name)


def add(a, b):
    return a + b


greet("Adarsh")

result = add(10, 20)
print("Addition:", result)
# Out:
# Hello Adarsh
# Addition: 30
