# %% [markdown]
# <a href="https://colab.research.google.com/github/AdarshMane09/module-1-ai-python/blob/main/factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = int(input("Enter a number: "))

factorial = 1

for i in range(1, number + 1):
    factorial = factorial * i

print("Factorial of", number, "is", factorial)
# Out:
# Enter a number: 15
# Factorial of 15 is 1307674368000
