# %% [markdown]
# <a href="https://colab.research.google.com/github/AdarshMane09/module-1-ai-python/blob/main/lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
subjects = ["English", "Python", "DBMS", "C++"]

print("Subjects:", subjects)

print("First subject:", subjects[0])

subjects.append("AI")
print("After adding AI:", subjects)

subjects.remove("C++")
print("After removing C++:", subjects)

print("Total subjects:", len(subjects))
# Out:
# Subjects: ['English', 'Python', 'DBMS', 'C++']
# First subject: English
# After adding AI: ['English', 'Python', 'DBMS', 'C++', 'AI']
# After removing C++: ['English', 'Python', 'DBMS', 'AI']
# Total subjects: 4
