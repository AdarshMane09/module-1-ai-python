# %% [markdown]
# <a href="https://colab.research.google.com/github/AdarshMane09/module-1-ai-python/blob/main/even_odd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = int(input("Enter a number: "))

if number % 2 == 0:
    print(number, "is an Even number")
else:
    print(number, "is an Odd number")
# Out:
# Enter a number: 2
# 2 is an Even number
